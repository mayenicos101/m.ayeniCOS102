# %%
print("Welcomet to the COUPE DE ESCRIVA 2023: FOOTBALL PICKS \n")
captain = {'Madiba: ': 'Chubby Obiora-Okafo', 'Blue Jays: ': 'Christopher Uweh', 'Cirok: ': 'Alexander', 'TSG Walkers: ': 'Ikechukwu'}

goalkeepers = {'Madiba: ': 'Chubby Obiora-Okafo', 'Blue Jays: ': 'Oladimeji Abaniwondea/Jeffery Awagu', 'Cirok: ': 'Timileyin Pearse/Izuako Jeremy', 'TSG Walkers: ': 'Ayomide Ojituku'}

for pick in captain:
    print(pick, captain[pick], 'is the captain of', pick)
print('\n')
for pick in goalkeepers:
    print(pick, goalkeepers[pick], 'is the goalkeeper of', pick)
# Out:
# Welcomet to the COUPE DE ESCRIVA 2023: FOOTBALL PICKS
#
# Madiba:  Chubby Obiora-Okafo is the captain of Madiba:
# Blue Jays:  Christopher Uweh is the captain of Blue Jays:
# Cirok:  Alexander is the captain of Cirok:
# TSG Walkers:  Ikechukwu is the captain of TSG Walkers:
#
#
# Madiba:  Chubby Obiora-Okafo is the goalkeeper of Madiba:
# Blue Jays:  Oladimeji Abaniwondea/Jeffery Awagu is the goalkeeper of Blue Jays:
# Cirok:  Timileyin Pearse/Izuako Jeremy is the goalkeeper of Cirok:
# TSG Walkers:  Ayomide Ojituku is the goalkeeper of TSG Walkers:
