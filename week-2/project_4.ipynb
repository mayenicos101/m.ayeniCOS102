# %%
while True:
    try:
        age = int(input("Enter your age: "))
        experience = int(input("Enter your work experience: "))
        break
    except ValueError:
        print("Invalid input. Please enter a valid number!")
        continue

match (experience, age):
    case (e, a) if e > 25 and a >=55:
        annual_tax_revenue = 5600000
    case (e, a) if e > 20 and a >= 45:
        annual_tax_revenue = 4480000
    case (e, a) if e > 10 and a >= 35:
        annual_tax_revenue = 1500000
    case _:
        annual_tax_revenue = 550000
        
print(f"Annual tax revenue: N{annual_tax_revenue}")
# Out:
# Invalid input. Please enter a valid number!
# Annual tax revenue: N4480000
