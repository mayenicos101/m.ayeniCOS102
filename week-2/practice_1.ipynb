# %%
city_1 = input('Enter name of City 1:')
city_2 = input('Enter name of City 2:')

temp = city_1
city_1 = city_2
city_2 = temp

print('City 1 is now:', city_1)
print('City 2 is now:', city_2)
# Out:
# City 1 is now: Abuja
# City 2 is now: Lagos
