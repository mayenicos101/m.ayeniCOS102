# %%
str1 = "Hi my name is Mosope. I am a String"
str2 = "Hi my name is Joseph. I am a String too"

print(str1)
print(type(str1))

print(str2)
print(type(str2))
# Out:
# Hi my name is Mosope. I am a String
# <class 'str'>
# Hi my name is Joseph. I am a String too
# <class 'str'>
